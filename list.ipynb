# %% [markdown]
# <a href="https://colab.research.google.com/github/srinath4304/srinath_4304_DS/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
nums = []
nums.append(10)
nums.append(20)
nums.append(30)
print(nums)
# Out:
# [10, 20, 30]
